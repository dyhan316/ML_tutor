# %%
import os

# %%
os.listdir('/Users/eunmi/Desktop/QSIPREP/SAMPLE_sample_sub/qsirecon/sub-200090/dwi/')
# Out:
# ['sub-200090_space-T1w_desc-preproc_desc-wmFOD_msmtcsd.txt',
#  'out_few.tck',
#  'sub-200090_space-T1w_desc-preproc_msmtconnectome.mat',
#  'sub-200090_space-T1w_desc-preproc_desc-mtinliermask_msmtcsd.nii.gz',
#  'sub-200090_space-T1w_desc-preproc_desc-siftweights_ifod2.csv',
#  'sub-200090_space-T1w_desc-preproc_desc-mtnorm_msmtcsd.nii.gz',
#  'sub-200090_space-T1w_desc-preproc_desc-csfFODmtnormed_msmtcsd.mif.gz',
#  'sub-200090_space-T1w_desc-preproc_desc-gmFODmtnormed_msmtcsd.mif.gz',
#  'sub-200090_space-T1w_desc-preproc_desc-csfFOD_msmtcsd.txt',
#  'sub-200090_space-T1w_desc-preproc_desc-gmFOD_msmtcsd.txt',
#  'sub-200090_space-T1w_desc-preproc_desc-wmFODmtnormed_msmtcsd.mif.gz']

# %%
path = '/Users/eunmi/Desktop/QSIPREP/SAMPLE_sample_sub/qsirecon/sub-200090/dwi/sub-200090_space-T1w_desc-preproc_msmtconnectome.mat'

# %%
path
# Out:
# '/Users/eunmi/Desktop/QSIPREP/SAMPLE_sample_sub/qsirecon/sub-200090/dwi/sub-200090_space-T1w_desc-preproc_msmtconnectome.mat'

# %%
import scipy
import scipy.io as sio

# %%
conn = sio.loadmat(path)

# %%
conn.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'aicha384_region_ids', 'aicha384_region_labels', 'aicha384_sift_invnodevol_radius2_count_connectivity', 'command', 'aicha384_radius2_meanlength_connectivity', 'aicha384_radius2_count_connectivity', 'aicha384_sift_radius2_count_connectivity', 'schaefer200x17_region_ids', 'schaefer200x17_region_labels', 'schaefer200x17_sift_invnodevol_radius2_count_connectivity', 'schaefer200x17_radius2_meanlength_connectivity', 'schaefer200x17_radius2_count_connectivity', 'schaefer200x17_sift_radius2_count_connectivity', 'schaefer100x17_region_ids', 'schaefer100x17_region_labels', 'schaefer100x17_sift_invnodevol_radius2_count_connectivity', 'schaefer100x17_radius2_meanlength_connectivity', 'schaefer100x17_radius2_count_connectivity', 'schaefer100x17_sift_radius2_count_connectivity', 'gordon333_region_ids', 'gordon333_region_labels', 'gordon333_sift_invnodevol_radius2_count_connectivity', 'gordon333_radius2_meanlength_connectivity', 'gordon333_radi
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(conn['schaefer200x7_sift_radius2_count_connectivity'])
